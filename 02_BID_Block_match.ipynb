# %% [markdown]
# ### Data Cleaning: Join BIDs to Blocks dataset

# %% [markdown]
# By ADA Group 1
#
# In this Jupyter Notebook, we will join the Business Improvement District (BID) information to the Block Level data using BIDs unique identifier number as a key.
#
# The Block level data was previously joined in GIS with BIDs shapefile. Therefore, the Blocks dataset includes a BID dummy variable and a BID unique identifier that we will use to join further BID information including BID creation year, assesed value and number of businesses.
#
# #### Data Sources
#
# * **BID data** NYC Small Business Services. Obtained from https://www1.nyc.gov/site/sbs/neighborhoods/bid-directory.page and NYC Open Data. Obatined from:  https://data.cityofnewyork.us/Business/Business-Improvement-Districts/ejxk-d93y/data
# * **Census Blocks data** Center for Urban Research, The Graduate Center, City University of New York (CUNY). Obtained from  http://www.urbanresearchmaps.org/plurality/blockmaps.htm
#
# For Data Dictionary, please refer to the notebook 00_ReadMe.

# %%
# general use imports
# %pylab inline
import datetime
import numpy as np
import os
import six
import warnings
import matplotlib.pyplot as plt
import re

# pandas-related imports
from __future__ import print_function
import pandas as pd
import scipy
import sklearn

# record linkage package
import recordlinkage as rl
from recordlinkage.preprocessing import clean, phonenumbers, phonetic

# CSV file reading-related imports
import csv

# sqlalchemy an psycopg2 are sql connection packages
from sqlalchemy import create_engine


print( "Imports loaded at " + str( datetime.datetime.now() ) )
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Imports loaded at 2018-04-24 23:46:22.016156

# %% [markdown]
# ### Load Bussines Improvement Districts data

# %%
df = pd.read_csv('../Data/bidsmerged_update__2_.csv') 
df.shape
# 75 rows and 22 columns
# Out:
# (75, 22)

# %%
df.count()
# Out:
# org_id              75
# assessment          75
# org_name            75
# org_address         73
# org_address2        55
# org_city            74
# org_state           74
# org_zip             73
# boro_id             75
# org_phone           72
# org_fax             63
# org_website         73
# org_email           74
# org_boundary        75
# org_neighborhood    74
# org_date            75
# org_month           75
# org_day             75
# org_year            75
# org_realestate      69
# org_blocks          72
# org_businesses      74
# dtype: int64

# %%
df.tail()
# Out:
#     org_id      assessment                             org_name  \
# 70      57  $8,800,000.00             Garment District Alliance
# 71      75          $0.00                           Morris Park
# 72    1397    $907,000.00         Court-Livingston-Schermerhorn
# 73       1  $2,004,500.00   Fulton Mall Improvement Association
# 74      22  $3,827,675.00                             MetroTech
#
#                              org_address  \
# 70                  209 West 38th Street
# 71                                   NaN
# 72     c/o Downtown Brooklyn Partnership
# 73     c/o Downtown Brooklyn Partnership
# 74  1 MetroTech Center North, Suite 1003
#
#                             org_address2  org_city org_state     org_zip  \
# 70                             2nd Floor  New York        NY       10018
# 71                                   NaN  New York        NY         NaN
# 72  1 MetroTech Center North, Suite 1003  Brooklyn        NY       11201
# 73  1 MetroTech Center North, Suite 1003  Brooklyn        NY       11201
# 74                                   NaN  Brooklyn        NY  11201-3858
#
#       boro_id   org_phone      ...                            org_email  \
# 70  Manhattan  2127649600      ...        bblair@garmentdistrictnyc.com
# 71      Bronx         NaN      ...              morrisparkbid@gmail.com
# 72   Brooklyn  7184031600      ...           rmyer@downtownbrooklyn.com
# 73   Brooklyn  7184031600      ...           rmyer@downtownbrooklyn.com
# 74   Brooklyn  7184031600      ...           rmyer@downtownbrooklyn.com
#
#                                          org_boundary   org_neighborhood  \
# 70  Area generally bounded by Fifth Avenue on the ...            Midtown
# 71  Morris Park Avenue from Williamsbridge Road to...        Morris Park
# 72  Area generally bounded by Court Street on the ...  Downtown Brooklyn
# 73  Fulton Street from Adams Street to Flatbush Av...  Downtown Brooklyn
# 74  Area generally bounded by Adams Street to the ...  Downtown Brooklyn
#
#    org_date org_month org_day  org_year  \
# 70   Oct-93        10       1      1993
# 71   18-Jan         1       1      2018
# 72    7-Jun         6       1      2007
# 73   Jun-76         6       1      1976
# 74   Jan-92         1       1      1992
#
#                                        org_realestate  org_blocks  \
# 70  The Garment District, located in the heart of ...        95.0
# 71                                                NaN         NaN
# 72  The area is a mixed-use neighborhood in the he...        68.0
# 73  Fulton Street Mall is considered one of the mo...        17.0
# 74  Located in the heart of 'America's Fourth Larg...        95.0
#
#    org_businesses
# 70          500.0
# 71            0.0
# 72          194.0
# 73          150.0
# 74          134.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Load Block Level data
# As mentioned above, this dataset was created in GIS by spatially joining the BID shapefile to the Census Block Groups Shapefile. Therefore, Blocks that belong to BIDs already have a BID unique identifier.

# %%
blocks= pd.read_csv("../Data/blocks_clean.csv", usecols=range(1,23))
blocks.head()
# Out:
#            BLOCKID  Pop10   Pop00  shWhite00  shLatino00  shBlack00  \
# 0  360050300004003    249   272.0  58.088235   37.132353   1.102941
# 1  360050409001001     11  1119.0   1.340483    9.562109  86.058981
# 2  360050409002000   3223  1886.0  26.988335    9.809120  59.172853
# 3  360050419001004    225   233.0  19.313305   60.944206   6.437768
# 4  360050449011006     28    28.0  71.428571   28.571429   0.000000
#
#    shAsian00  shOther00  pct_ch_white  pct_ch_hisp    ...     pct_ch_other  \
# 0   2.941176   0.735294    -17.525986     9.453992    ...         3.280770
# 1   0.983021   2.055407     -1.340483    -9.562109    ...        -2.055407
# 2   1.855779   2.173913    -12.498729     1.422652    ...         0.401327
# 3  11.587983   1.716738     -5.535527    -8.944206    ...        -0.383405
# 4   0.000000   0.000000     -3.571429    -7.142857    ...         0.000000
#
#    pop_pct_ch  BoroName  NTACode                              NTAName  \
# 0   91.544118     Bronx     BX10  Pelham Bay-Country Club-City Island
# 1    0.983021     Bronx     BX43                              Norwood
# 2  170.890774     Bronx     BX05           Bedford Park-Fordham North
# 3   96.566524     Bronx     BX43                              Norwood
# 4  100.000000     Bronx     BX62                   Woodlawn-Wakefield
#
#     A_poly bid_id  bid_name  a_weight BID_dummy
# 0   173964    NaN       NaN       1.0         0
# 1  1387986    NaN       NaN       1.0         0
# 2   833865    NaN       NaN       1.0         0
# 3    48578    NaN       NaN       1.0         0
# 4    49237    NaN       NaN       1.0         0
#
# [5 rows x 22 columns]

# %%
blocks.head()
# Out:
#            BLOCKID  Pop10   Pop00  shWhite00  shLatino00  shBlack00  \
# 0  360050300004003    249   272.0  58.088235   37.132353   1.102941
# 1  360050409001001     11  1119.0   1.340483    9.562109  86.058981
# 2  360050409002000   3223  1886.0  26.988335    9.809120  59.172853
# 3  360050419001004    225   233.0  19.313305   60.944206   6.437768
# 4  360050449011006     28    28.0  71.428571   28.571429   0.000000
#
#    shAsian00  shOther00  pct_ch_white  pct_ch_hisp    ...     pct_ch_other  \
# 0   2.941176   0.735294    -17.525986     9.453992    ...         3.280770
# 1   0.983021   2.055407     -1.340483    -9.562109    ...        -2.055407
# 2   1.855779   2.173913    -12.498729     1.422652    ...         0.401327
# 3  11.587983   1.716738     -5.535527    -8.944206    ...        -0.383405
# 4   0.000000   0.000000     -3.571429    -7.142857    ...         0.000000
#
#    pop_pct_ch  BoroName  NTACode                              NTAName  \
# 0   91.544118     Bronx     BX10  Pelham Bay-Country Club-City Island
# 1    0.983021     Bronx     BX43                              Norwood
# 2  170.890774     Bronx     BX05           Bedford Park-Fordham North
# 3   96.566524     Bronx     BX43                              Norwood
# 4  100.000000     Bronx     BX62                   Woodlawn-Wakefield
#
#     A_poly bid_id  bid_name  a_weight BID_dummy
# 0   173964    NaN       NaN       1.0         0
# 1  1387986    NaN       NaN       1.0         0
# 2   833865    NaN       NaN       1.0         0
# 3    48578    NaN       NaN       1.0         0
# 4    49237    NaN       NaN       1.0         0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Merge the two datasets
# We inner merge BIDs to Blocks, using bid_id on the Blocks datasets and org_id on BIDs dataset.N The new dataset would have additional BID information such as formation years, the organization email etc.

# %%
blocksBID=blocks.merge(df, left_on='bid_id', right_on='org_id', how='inner')
blocksBID.head()
# Out:
#            BLOCKID  Pop10       Pop00  shWhite00  shLatino00  shBlack00  \
# 0  360050389002001    186  117.199997  25.597270   55.460752  15.358362
# 1  360050389002003    299  299.000000  33.779264   59.866221   4.347826
# 2  360050389003005    157  146.000000  47.945205   39.726027   6.164384
# 3  360050389003003    269  210.000000  27.619048   67.619048   1.428571
# 4  360050391006001    454  452.000000  28.097345   64.159292   0.221239
#
#    shAsian00  shOther00  pct_ch_white  pct_ch_hisp      ...        \
# 0   0.853242   3.412969     44.295203   -32.880107      ...
# 1   1.337793   0.668896     -7.357860     5.351171      ...
# 2   0.684932   5.479452     -3.359218     4.859960      ...
# 3   0.952381   2.380952      5.094707    -6.652505      ...
# 4   3.539823   3.982301     -8.053292     3.682118      ...
#
#                     org_email  \
# 0  execdirector@pitkinbid.org
# 1  execdirector@pitkinbid.org
# 2  execdirector@pitkinbid.org
# 3  execdirector@pitkinbid.org
# 4  execdirector@pitkinbid.org
#
#                                         org_boundary  org_neighborhood  \
# 0  Pitkin Avenue from Howard Avenue to Mother Gas...       Brownsville
# 1  Pitkin Avenue from Howard Avenue to Mother Gas...       Brownsville
# 2  Pitkin Avenue from Howard Avenue to Mother Gas...       Brownsville
# 3  Pitkin Avenue from Howard Avenue to Mother Gas...       Brownsville
# 4  Pitkin Avenue from Howard Avenue to Mother Gas...       Brownsville
#
#    org_date org_month org_day org_year  \
# 0    Oct-93        10       1     1993
# 1    Oct-93        10       1     1993
# 2    Oct-93        10       1     1993
# 3    Oct-93        10       1     1993
# 4    Oct-93        10       1     1993
#
#                                       org_realestate  org_blocks  \
# 0  The Pitkin Avenue BID is comprised of 10 block...        32.0
# 1  The Pitkin Avenue BID is comprised of 10 block...        32.0
# 2  The Pitkin Avenue BID is comprised of 10 block...        32.0
# 3  The Pitkin Avenue BID is comprised of 10 block...        32.0
# 4  The Pitkin Avenue BID is comprised of 10 block...        32.0
#
#   org_businesses
# 0          180.0
# 1          180.0
# 2          180.0
# 3          180.0
# 4          180.0
#
# [5 rows x 44 columns]

# %%
blocksBID.to_csv("../Data/block_dummies_BIDS.csv", encoding='utf8')
